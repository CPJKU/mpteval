# %%
import partitura as pt

from mpteval.articulation import articulation_metrics_from_perf
from mpteval.timing import timing_metrics_from_perf
from mpteval.harmony import harmony_metrics_from_perf
from mpteval.dynamics import dynamics_metrics_from_perf

true_midi = 'testfile_monophonic.mid'
true_perf = pt.load_performance_midi(true_midi)

articulation_metrics_from_perf(true_perf, true_perf)
timing_metrics_from_perf(true_perf, true_perf)
harmony_metrics_from_perf(true_perf, true_perf)
dynamics_metrics_from_perf(true_perf, true_perf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 14
#      12 timing_metrics_from_perf(true_perf, true_perf)
#      13 harmony_metrics_from_perf(true_perf, true_perf)
# ---> 14 dynamics_metrics_from_perf(true_perf, true_perf)
#
# File ~/work/mpteval/mpteval/dynamics.py:302, in dynamics_metrics_from_perf(ref_perf, pred_perf, use_true_note_offs, r_b)
#     299 ref_note_array = ref_perf.note_array()
#     300 pred_note_array = pred_perf.note_array()
# --> 302 ref_dynamic_range_func, *_ = get_upper_lower_stream_dynamic_range(
#     303     note_array=ref_note_array,
#     304     r_b=r_b,
#     305 )
#     307 pred_dynamic_range_func, *_ = get_upper_lower_stream_dynamic_range(
#     308     note_array=pred_note_array,
#     309     r_b=r_b,
#     310 )
#     312 # Compute correlation between reference and predicted dynamic range functions
#
# File ~/work/mpteval/mpteval/dynamics.py:262, in get_upper_lower_stream_dynamic_range(note_array, r_b, ioi_threshold, max_threshold)
#     252 lower_voice_vel_func = interp1d(
#     253     x=lower_voice["onset_sec"],
#     254     y=lower_voice["velocity"],
#    (...)
#     258     fill_value=1e-6,
#     259 )
#     261 vel_upper = upper_voice_vel_func(note_array["onset_sec"])
# --> 262 vel_lower = lower_voice_vel_func(note_array["onset_sec"])
#     264 dynamic_range = dynamic_range_in_db(
#     265     vel1=vel_upper,
#     266     vel2=vel_lower,
#     267     r_b=r_b,
#     268 )
#     270 dynamic_range_func = interp1d(
#     271     x=note_array["onset_sec"],
#     272     y=dynamic_range,
#    (...)
#     276     fill_value=-r_b,
#     277 )
#
# File ~/.conda/envs/mpteval/lib/python3.9/site-packages/partitura/utils/generic.py:592, in interp1d.<locals>.typed_interp(input_var)
#     589 def typed_interp(
#     590     input_var: Union[float, int, np.ndarray]
#     591 ) -> Callable[[Union[float, int, np.ndarray]], np.ndarray]:
# --> 592     return interp_fun(input_var).astype(dtype)
#
# File ~/.conda/envs/mpteval/lib/python3.9/site-packages/partitura/utils/generic.py:579, in interp1d.<locals>.interp_fun(input_var)
#     577     result = np.broadcast_to(y, (len(np.atleast_1d(input_var)), y.shape[1]))
#     578 else:
# --> 579     result = np.broadcast_to(y, (len(np.atleast_1d(input_var)),))
#     581 if not isinstance(input_var, np.ndarray):
#     582     # the output of scipy's interp1d is always an array
#     583     result = np.array(result[0])
#
# File ~/.conda/envs/mpteval/lib/python3.9/site-packages/numpy/lib/stride_tricks.py:413, in broadcast_to(array, shape, subok)
#     367 @array_function_dispatch(_broadcast_to_dispatcher, module='numpy')
#     368 def broadcast_to(array, shape, subok=False):
#     369     """Broadcast an array to a new shape.
#     370
#     371     Parameters
#    (...)
#     411            [1, 2, 3]])
#     412     """
# --> 413     return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File ~/.conda/envs/mpteval/lib/python3.9/site-packages/numpy/lib/stride_tricks.py:349, in _broadcast_to(array, shape, subok, readonly)
#     346     raise ValueError('all elements of broadcast shape must be non-'
#     347                      'negative')
#     348 extras = []
# --> 349 it = np.nditer(
#     350     (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     351     op_flags=['readonly'], itershape=shape, order='C')
#     352 with it:
#     353     # never really has writebackifcopy semantics
#     354     broadcast = it.itviews[0]
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (0,)  and requested shape (84,)
